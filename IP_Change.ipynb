# %%
import pandas as pd 
df = pd.read_csv (r'/Users/sehan/Documents/Slowloris/slowloris.csv')
display(df)
# Out:
#          SrcId   Rank        StartTime         LastTime  Trans        Flgs  \
# 0      0.0.0.0      1  14:45:20.821783  14:45:20.821783      1   e
# 1      0.0.0.0      2  14:45:20.883104  14:45:21.036739      1   e
# 2      0.0.0.0      3  14:45:21.082679  14:45:21.082679      1   e
# 3      0.0.0.0      4  14:45:21.243699  14:45:26.243144      1   e
# 4      0.0.0.0      5  14:45:21.243809  14:45:26.241059      1   e
# ...        ...    ...              ...              ...    ...         ...
# 12068  0.0.0.0  12069  14:55:15.771120  14:55:15.771120      1   e
# 12069  0.0.0.0  12070  14:55:16.027797  14:55:16.027797      1   e
# 12070  0.0.0.0  12071  14:55:16.295293  14:55:16.324764      1   e
# 12071  0.0.0.0  12072  14:55:16.284842  14:55:16.284842      1   e
# 12072  0.0.0.0  12073  14:55:16.503944  14:55:16.503944      1   e
#
#         Seq       Dur   RunTime      IdleTime  ...  sVpri  dVpri  SRange  \
# ...

# %%
# Converting IP address columns to a list
sourceip = df[str('src_ip')].tolist()
destinationip = df[str('dst_ip')].tolist()

print('Source IP:', sourceip)
print('Destination IP', destinationip)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'src_ip'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-243-bfa17e9e9c97> in <module>
# ...

# %%
type(sourceip[i])
# Out:
# int

# %%
for i in range(len(sourceip)):
    x = sourceip[i]
    z = ''
    parts = x.split('.')
    for j in range(4):
        if len(parts[j]) == 3:
            z = z + parts[j] 
        elif len(parts[j]) == 2:
            z = z + '0' + parts[j] 
        else:
            z = z + '00' + parts[j]
        sourceip[i] = int(z)
    print('sourceip:', sourceip[i])
    y = destinationip[i]
    k = ''
    part = y.split('.')
    for r in range(4):
        if len(part[r]) == 3:
            k = k + part[r]
        elif len(parts[j]) == 2:
            k = k + '0' + part[r]
        else:
            k = k + '00' + parts[r]
        destinationip[i] = int(k)
    print('destinationip:', destinationip[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-245-d24b2f57ff2a> in <module>
#       2     x = sourceip[i]
#       3     z = ''
# ----> 4     parts = x.split('.')
#       5     for j in range(4):
#       6         if len(parts[j]) == 3:
#
# AttributeError: 'int' object has no attribute 'split'

# %%
output = pd.DataFrame ({"src_ip":sourceip, "dst_ip":destinationip})
display(output)
# Out:
#            src_ip           dst_ip
# 0     10155015011     142250074074
# 1     10155015000    1000155145132
# 2     10255248200  100025515000200
# 3     10155015009    1081770015100
# 4     10155015000    1081770015101
# ...           ...              ...
# 3185  10155015011     142250074106
# 3186  10155015009    1422500015142
# 3187  10155015010      74125131188
# 3188  10155015011      74125131188
# 3189  74125100006    7415500100006
#
# [3190 rows x 2 columns]

# %%
header_list = ['src_ip', 'dst_ip']
output.to_csv('/Users/sehan/Documents/Slowloris/slowloris_processed.csv', header=header_list, index=False)

# %%
for i in range(len(destinationip)):
    x = destinationip[i]
    z = ''
    parts = x.split('.')
    for j in range(4):
        if len(parts[j]) == 3:
            z = z + parts[j] 
        elif len(parts[j]) == 2:
            z = z + '0' + parts[j] 
        else:
            z = z + '00' + parts[j]
        destinationip[i] = int(z)
    print('destinationip:', destinationip[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-238-5238760a83fb> in <module>
#       2     x = destinationip[i]
#       3     z = ''
# ----> 4     parts = x.split('.')
#       5     for j in range(4):
#       6         if len(parts[j]) == 3:
#
# AttributeError: 'int' object has no attribute 'split'

# %%
def ipchange(ip):
    part = ip.split('.')
    result = []
    con = ""
    for number in part:
        result.append("0"*(3-len(number)) + number)
        print(result)
    return int(con.join(result))
print(ipchange(sourceip[i]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-16a9e93f4c7d> in <module>
#       7         print(result)
#       8     return int(con.join(result))
# ----> 9 print(ipchange(sourceip[i]))
#
# <ipython-input-154-16a9e93f4c7d> in ipchange(ip)
#       1 def ipchange(ip):
# ----> 2     part = ip.split('.')
#       3     result = []
#       4     con = ""
#       5     for number in part:
#
# AttributeError: 'int' object has no attribute 'split'

# %%
for i in range(len(sourceip)):   
    print(ipchange(sourceip))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-eb886393f9f1> in <module>
#       1 for i in range(len(sourceip)):
# ----> 2     print(ipchange(sourceip))
#
# <ipython-input-133-6d944102a96e> in ipchange(ip)
#       1 def ipchange(ip):
# ----> 2     part = ip.split('.')
#       3     result = []
#       4     con = ""
#       5     for number in part:
#
# AttributeError: 'list' object has no attribute 'split'
